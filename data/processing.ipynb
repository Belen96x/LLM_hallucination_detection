# %%
import pandas as pd

# %%
df = pd.read_csv(fr'C:\Users\belen\Desktop\Erasmus\Universidad del País Vasco\Machine_translation\data\halomi_full.tsv', sep = '\t')

# %%
df.head()
df.shape[0]
# Out:
# 5247

# %%
# Define allowed languages
allowed_languages = {'spa_Latn', 'eng_Latn'}

# Filter the DataFrame
filtered_df = df[
    df['src_lang'].isin(allowed_languages) & 
    df['tgt_lang'].isin(allowed_languages)
]

# %%
filtered_df.to_csv('data.csv')

# %%
filtered_df.head()
filtered_df['class_hall'].value_counts()
# Out:
# class_hall
# 1_No_hallucination         361
# 3_Partial_hallucination    124
# 2_Small_hallucination       58
# 4_Full_hallucination        49
# Name: count, dtype: int64

# %%
filtered_df.head()
# Out:
#      src_lang  tgt_lang                                           src_text  \
# 169  spa_Latn  eng_Latn  Si deseas aprender cómo lanzar un búmeran y qu...
# 170  spa_Latn  eng_Latn  «Si se empieza a comercializar, deberíamos ten...
# 171  spa_Latn  eng_Latn  En la actualidad, brindar hospedaje y desayuno...
# 172  spa_Latn  eng_Latn  A ver como opinan los otro bilbiotecarios de l...
# 173  spa_Latn  eng_Latn  Siempre se ha llamado y seguirá llamando BANDO...
#
#                                                mt_text  \
# 169  If you want to learn how to throw a buffalo an...
# 170  "If it's going to be commercialized, we should...
# 171  Today, providing luxurious accommodation and b...
# 172  Let's see what the other fucked-up bilbiotecar...
# 173        He's always called and he's always calling.
#
#                                             omit_spans  \
# 169  Si deseas aprender cómo lanzar un <<<búmeran>>...
# 170  «Si se empieza a comercializar, deberíamos ten...
# ...
